# %%
# !pip install transformers
# !pip gdown
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# ERROR: unknown command "gdown" - maybe you meant "download"

# %%
import gdown

url = 'https://drive.google.com/uc?id=11ZZ5iO9HqahU_T3JP5DtPZi0uJI6eQEj'
output = 'kogpt_comment_reply_model.pt'  # 원하는 파일 이름과 확장자로 변경
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=11ZZ5iO9HqahU_T3JP5DtPZi0uJI6eQEj
# From (redirected): https://drive.google.com/uc?id=11ZZ5iO9HqahU_T3JP5DtPZi0uJI6eQEj&confirm=t&uuid=9b19120c-52f4-45b3-b74e-b978873f27f5
# To: /content/kogpt_comment_reply_model.pt
# 100%|██████████| 501M/501M [00:05<00:00, 93.2MB/s]
# 'kogpt_comment_reply_model.pt'

# %%
# 필요한 라이브러리를 임포트합니다.
import torch
from transformers import GPT2Config, GPT2LMHeadModel, PreTrainedTokenizerFast

# 대화에서 사용할 특별 토큰들을 정의합니다.
Q_TKN = "<usr>" # 사용자 입력을 나타내는 토큰
A_TKN = "<sys>" # 시스템의 응답을 나타내는 토큰
BOS = '</s>'    # 문장의 시작을 나타내는 토큰
EOS = '</s>'    # 문장의 종료를 나타내는 토큰
MASK = '<unused0>'  # 마스크 토큰
SENT = '<unused1>'  # 문장 분류를 위한 토큰
PAD = '<pad>'   # 패딩 토큰

# 사전 훈련된 토크나이저를 로드합니다. 토크나이저는 텍스트를 모델이 처리할 수 있는 형태로 변환합니다.
koGPT2_TOKENIZER = PreTrainedTokenizerFast.from_pretrained("skt/kogpt2-base-v2",
                    bos_token=BOS, eos_token=EOS, unk_token='<unk>',
                    pad_token=PAD, mask_token=MASK)

# 사전 훈련된 모델의 구성을 로드합니다.
config = GPT2Config.from_pretrained('skt/kogpt2-base-v2')
# 사전 훈련된 모델을 로드합니다.
model = GPT2LMHeadModel(config)
# 사전 훈련된 모델의 가중치를 로드합니다. CPU를 사용하여 로드합니다.
model.load_state_dict(torch.load('kogpt_comment_reply_model.pt', map_location=torch.device('cpu')))
# 모델을 평가 모드로 설정합니다. 이 모드에서는 모델이 학습 중이 아닐 때의 동작을 합니다.
model.eval()

# 문장 분류를 위한 토큰을 초기화합니다.
sent = "0"

# 모델을 사용하여 답변을 생성하는 함수를 정의합니다.
def dl_model(input_text, max_length=64):

    response = ""   # 응답을 초기화합니다.

    # 최대 길이만큼 반복하여 응답을 생성합니다.
    for _ in range(max_length):

        # 0 Q_TKN + "맛있네요." + SENT + sent + A_TKN + "" > model > response (감)
        # 1 Q_TKN + "맛있네요." + SENT + sent + A_TKN + "감" > model > response (사)
        # 2 Q_TKN + "맛있네요." + SENT + sent + A_TKN + "감사" > model > response (합)
        # 3 Q_TKN + "맛있네요." + SENT + sent + A_TKN + "감사합" > model > response (니)
        # 4 Q_TKN + "맛있네요." + SENT + sent + A_TKN + "감사합니" > model > response (다)
        # 5 Q_TKN + "맛있네요." + SENT + sent + A_TKN + "감사합니다" > model > response (.)
        # 6 Q_TKN + "맛있네요." + SENT + sent + A_TKN + "감사합니다." > model > response (EOS)

        # 입력 텍스트를 모델이 처리할 수 있는 형태로 인코딩합니다.
        input_ids = torch.LongTensor(koGPT2_TOKENIZER.encode(Q_TKN + input_text + SENT + sent + A_TKN + response)).unsqueeze(dim=0)

        # 입력 중 어느 부분이 패딩인지를 나타내는 마스크를 생성합니다.
        attention_mask = input_ids != koGPT2_TOKENIZER.pad_token_id

        # 모델을 사용하여 예측을 수행합니다.
        pred = model(input_ids, attention_mask=attention_mask)
        pred = pred.logits

        # 예측 결과 중 가장 확률이 높은 토큰을 선택합니다.
        gen = koGPT2_TOKENIZER.convert_ids_to_tokens(torch.argmax(pred, dim=-1).squeeze().numpy().tolist())[-1]

        # 생성된 토큰이 문장의 끝을 나타내면 반복을 종료합니다.
        if gen == EOS:
            break

        # 생성된 토큰을 응답에 추가합니다. 토큰의 시작 부분에 있는 공백을 제거합니다.
        response += gen.replace("▁", " ")

    return response.strip()
# Out:
# tokenizer.json:   0%|          | 0.00/2.83M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT2Tokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.

# %%
import urllib.request
import pandas as pd
from sklearn.metrics import accuracy_score, confusion_matrix

def generate_reply(input_text):
    output = dl_model(input_text)
    return output

urllib.request.urlretrieve(
    "https://raw.githubusercontent.com/tykimos/tykimos.github.io/master/warehouse/dataset/tarrr_sample_submit.txt",
    filename="tarrr_sample_submit.txt",
)

# 파일을 DataFrame으로 로드
df = pd.read_csv('tarrr_sample_submit.txt', delimiter='\t')

for index, row in df.iterrows():
    comment = row['comment']
    reply = generate_reply(comment)

    print(f"[{index}]")
    print("comment : ", comment)
    print("reply : ", reply)
    print("---------------")
# Out:
# [0]
# comment :  완전 내 스타일이에요! 가격도 적당하고 위치도 좋고👌
# reply :  완전 내 스타일이에요! 고객님의 의견을 소중히 여기며, 가격과 위치 모두 만족시킬 수 있도록 노력하겠습니다. 다음에도 저희 가게를 찾아주셔서 감사합니다. 다음에도 저희 가게를 찾아주셔서 더 나은 경험을 드리도록 하겠습니다.
# ---------------
# [1]
# comment :  맛있긴 한데 양이 너무 적어서 좀... ㅠ
# reply :  양에 대한 의견 감사합니다. 양에 대한 의견 감사합니다. 더 많은 양을 준비하도록 하겠습니다.
# ---------------
# [2]
# comment :  완전 내 스타일이에요 ㅠㅠ 여기 매장 분위기도 이쁨
# reply :  완전 내 스타일이에요! 매장 분위기와 함께 좋은 시간 보내셨다니 기쁩니다! 앞으로도 편안하고 즐거운 매장 환경을 제공하기 위해 노력하겠습니다.
# ---------------
# [3]
# comment :  한국의 전통 음식을 잘 표현한 것 같아요. 향토음식의 정취가 느껴져 좋았습니다.
# reply :  한국의 전통 음식을 잘 표현해 냈다니 기쁩니다. 감사합니다!
# ---------------
# [4]
# comment :  서빙하는 분이 좀 불친절해서 기분이 좀 그랬어요.
# reply :  서비스에 불만족하셨다니 진심으로 사과드립니다. 직원 교육을 더 철저히 진행하겠습니다.
# ---------------
# [5]
# comment :  여기빵 왜이렇게맛있죠? 대박인데?
# reply :  맛에 대한 피드백 감사합니다. 고객님의 피드백을 통해 더욱 향상된 맛을 제공하도록 노력하겠습니다.
# ---------------
# [6]
# comment :  맛은 있는데, 가격이 너무 비싸서 가성비는 별로였어요.
# reply :  맛에 대한 피드백 감사합니다. 가격과 가치의 균형을 위해 노력하겠습니다.
# ---------------
# [7]
# comment :  ㅁㅊ... 여기 진짜 미친듯이 맛있음. 또 올듯ㅋㅋ
# reply :  맛에 만족하셨다니 정말 기쁩니다! 앞으로도 변함없이 만족을 드릴 수 있도록 노력하겠습니다.
# ---------------
# [8]
# comment :  ㅇㅈㄹㅇ ㅋㅋ 여기 왜 이제야 알았을까 싶네
# reply :  죄송합니다. 더 철저한 관리로 더 나은 서비스를 제공하겠습니다.
# ---------------
# [9]
# comment :  직원 한명이 너무 불친절했어요. 그냥 기분 나빴음.
# reply :  직원 태도에 대해 불편을 드려 죄송합니다. 직원 교육을 더 철저히 진행하겠습니다.
# ---------------
# [10]
# comment :  전체적인 분위기나 인테리어는 괜찮았는데, 청결도가 좀 아쉬워요.
# reply :  청결 문제에 대해 지적해 주셔서 감사합니다. 이 문제를 즉시 해결하고, 청결 유지에 더욱 힘쓰겠습니다. 불편을 드려 죄송하며, 다음 방문시 더 나은 환경을 제공하기 위해 최선을 다하겠습니다.
# ---------------
# [11]
# comment :  여기 김치 진짜 최고임 ㅋㅋ 내가 먹어본 김치 중 1등
# reply :  김치 맛에 만족하셨다니 정말 기쁩니다! 앞으로도 변함없이 맛있고 퀄리티 높은 김치 제공을 위해 노력하겠습니다. 다음에도 저희 김치 맛을 즐기러 오시<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# ---------------
# [12]
# comment :  이 집 김치찌개 진짜 대박임. 꼭 먹어보세용
# reply :  김치찌개, 맛있게 드셨다니 감사합니다! 앞으로도 김치찌개, 맛있게 드실 수 있도록 노력하겠습니다.
# ---------------
# [13]
# comment :  왜 이렇게 평이 좋은지 모르겠음.. 나에겐 그냥 그랬어.
# reply :  기대에 미치지 못한 점 죄송합니다. 더 나은 서비스를 위해 노력하겠습니다.
# ---------------
# [14]
# comment :  소문대로의 명성! 이런 곳이 내 동네에 있다니 행복해요.
# reply :  소문대로의 명성! 앞으로도 좋은 맛으로 보답하겠습니다.
# ---------------
# [15]
# comment :  다른 음식점과는 차별화된 맛이 있어요. 독특한데 맛있어요!
# reply :  다른 메뉴는 만족하셨지만 다른 맛을 선호하셨다니 유감입니다. 다른 메뉴도 만족하실 수 있도록 노력하겠습니다.
# ---------------
# [16]
# comment :  저는 별로였는데, 친구는 좋다고 하더라고요. 개인의 차이인 듯.
# reply :  친구의 입맛도 만족시키려 노력하고 있습니다. 다양한 메뉴로 두 분 모두 만족하실 수 있도록 노력하겠습니다.
# ---------------
# [17]
# comment :  이게 뭐야? 돈 주고 먹는 음식이 이 모양이야?
# reply :  돈 주고 먹는 음식이 많아 유감입니다. 고객님의 의견을 진지하게 받아들여 개선하겠습니다.
# ---------------
# [18]
# comment :  후기 좋아서 왔는데, 솔직히 기대 이하였어요.
# reply :  후기 만족하셨는데 실망이 크셨다니 정말 죄송합니다. 고객님의 기대를 충족시키지 못해 정말 유감입니다. 더 좋은 서비스로 보답하겠습니다.
# ---------------
# [19]
# comment :  지금까지 먹어본 중 최고의 냉면이에요. 육수도 깊고 면발이 쫄깃해요!
# reply :  냉면이에 만족하셨다니 감사합니다! 계속해서 좋은 냉면으로 고객님을 만족시키기 위해 노력하겠습니다.
# ---------------
# [20]
# comment :  서비스 개불친절 ㅡㅡ다신안옴
# reply :  서비스에 대한 불만을 드려 죄송합니다. 서비스 개선에 힘쓰겠습니다.
# ---------------
# [21]
# comment :  대기 시간이 좀 있었지만, 그래도 맛있게 잘 먹었어요.
# reply :  대기 시간이 길었다는 점, 진심으로 죄송합니다. 더 원활한 서비스를 위해 노력하겠습니다.
# ---------------
# [22]
# comment :  종업원분들이 정말 친절하셔서 기분 좋게 식사했어요.
# reply :  친절한 서비스와 편안한 식사 환경을 위해 노력하겠습니다. 다음에도 미소 가득한 서비스로 모시겠습니다.
# ---------------
# [23]
# comment :  진짜 제 인생 맛집! 다음에도 꼭 다시 오고 싶어요.
# reply :  정말 감사합니다! 다음에도 꼭 방문해주세요!
# ---------------
# [24]
# comment :  직원들이 너무 친절하셔서 좋았어요. 위치도 좋아서 자주 올 것 같아요.
# reply :  직원들의 친절함이 기억에 남아주셔서 감사합니다! 앞으로도 친절한 서비스로 모시겠습니다.
# ---------------
# [25]
# comment :  테이블 위에 먼지가 많아서 기분이 좀 불쾌했어요.
# reply :  테이블 위의 먼지가 기분 나빠서 불편을 드려 죄송합니다. 이 문제를 즉시 해결하고, 앞으로는 더욱 주의 깊게 청결을 유지하겠습니다. 불편을 드려 죄송하며, 다음 방문시 더 나은 환경을 제공하기 위해 최선을 다하겠습니다.
# ---------------
# [26]
# comment :  음식 나오는데 너무오래걸리더라ㅡㅡ 그래도 맛은 굿
# reply :  음식 준비에 더 신경쓰겠습니다. 다음에도 기대에 부응하도록 노력하겠습니다.
# ---------------
# [27]
# comment :  왜 이렇게 사람들이 많은지 알겠더라고요. 맛과 서비스 모두 만족!
# reply :  사람들의 입맛도 만족시키려 노력하고 있습니다. 앞으로도 최선을 다하겠습니다.
# ---------------
# [28]
# comment :  음식이 맛있긴한데 가격대비 양이 너무 적어서 별로였음.
# reply :  양에 대한 의견 감사합니다. 가격과 음식에 대한 고려를 더 하도록 하겠습니다.
# ---------------
# [29]
# comment :  서비스 개노답. 다신 안올듯.
# reply :  서비스에 대한 불만을 드려 죄송합니다. 피드백 감사합니다.
# ---------------
# [30]
# comment :  여기 카레는 다른 데서 먹던 것과는 달라요. 독특한 맛이 잘 어우러진다는 느낌?
# reply :  맛에 만족하셨다니 다행입니다. 계속해서 새로운 맛과 경험을 제공하려 노력하겠습니다.
# ---------------
# [31]
# comment :  여기 메뉴 다 맛있어서 뭐 시킬지 고민됨 ㅋㅋ 다음에는 뭘 먹지? 🤔
# reply :  메뉴 선택에 더욱 신경 쓰겠습니다. 다음에도 메뉴 선택에 도움 드리겠습니다.
# ---------------
# [32]
# comment :  서비스도 맛도 모두 최고! 여기 자주 올거같아요
# reply :  서비스에 만족하셨다니 감사합니다! 앞으로도 만족하실 수 있는 서비스를 제공하기 위해 노력하겠습니다.
# ---------------
# [33]
# comment :  바닷가 옆에서 먹는 해산물, 진짜 최고의 조합이에요!
# reply :  바닷가에서의 식사는 정말 감사합니다! 항상 최고의 조합으로 준비하겠습니다.
# ---------------
# [34]
# comment :  저번에 온 것보다 맛이 떨어지는 것 같아요. 변한 거 있나요?
# reply :  맛의 하락을 느끼셨다니 진심으로 사과드립니다. 지속적인 향상을 위해 노력하겠습니다.
# ---------------
# [35]
# comment :  여기 진짜 소문대로네요. 메뉴 하나하나 다 만족!
# reply :  소문대로의 만족을 드렸다니 정말 기쁩니다! 앞으로도 변함없이 맛있는 음식을 제공하겠습니다.
# ---------------
# [36]
# comment :  아무리 바빠도 기본적인 서비스는 지켜야 하는 거 아닌가요?
# reply :  바쁜 시간대의 서비스에 대한 불만을 드려 죄송합니다. 서비스 향상을 위해 노력하겠습니다.
# ---------------
# [37]
# comment :  매장이 좀 낡은 느낌? 조금만 리모델링 해주셨으면...
# reply :  매장이 낡은 느낌을 드려 죄송합니다. 고객님의 소중한 의견을 통해 개선해 나가도록 하겠습니다.
# ---------------
# [38]
# comment :  ㅇㅇ 여기 분위기랑 음식 모두 괜찮았어요.
# reply :  분위기와 음식 모두 만족하셨다니 다행입니다. 다음에도 기대에 부응하도록 노력하겠습니다.
# ---------------
# [39]
# comment :  ㅇㅇ 여기 분위기랑 음식 모두 괜찮았어요.
# reply :  분위기와 음식 모두 만족하셨다니 다행입니다. 다음에도 기대에 부응하도록 노력하겠습니다.
# ---------------
# [40]
# comment :  제 친구 추천으로 왔는데, 진짜 ㅇㅈ!
# reply :  친구의 추천으로 오셨다니 감사합니다! 앞으로도 좋은 추억 만들어드릴게요!
# ---------------
# [41]
# comment :  음식 맛은 괜찮은데, 위생상태가 좀 😖
# reply :  음식 맛에 대한 피드백 감사합니다. 위생관리를 더 철저히 하겠습니다.
# ---------------
# [42]
# comment :  주방에서 소리가 너무 크게 들려서 조금 불편했네요.
# reply :  소음으로 인해 불편을 드려 죄송합니다. 주방의 작업 환경 개선을 통해 더 쾌적한 식사 환경을 제공하도록 노력하겠습니다.
# ---------------
# [43]
# comment :  맛은 있었는데, 대기시간이 너무 길어서 별로였어.
# reply :  맛에 대한 피드백 감사합니다. 더 나은 맛을 제공하기 위해 노력하겠습니다.
# ---------------
# [44]
# comment :  외국인 친구들이랑 왔는데, 모두 만족했어요. 한국 음식 문화를 잘 느낄 수 있었습니다.
# reply :  외국인 친구분들과 좋은 시간 보내셨다니 기쁩니다. 앞으로도 좋은 추억 만들어드릴게요!
# ---------------
# [45]
# comment :  전반적으로는 만족! 다만, 좀더 청결했으면 좋겠어요.
# reply :  청결 문제에 대해 지적해 주셔서 감사합니다. 이 문제를 즉시 해결하고, 청결 유지에 더욱 힘쓰겠습니다. 다음 번에는 더욱 주의 깊게 청결을 유지하겠습니다.
# ---------------
# [46]
# comment :  음식은 좋은데, 서빙하는 분이 너무 느리셔서 기다리느라 지쳤어요.
# reply :  서비스 속도가 늦어져 불편을 드려 죄송합니다. 서비스 속도를 개선하여 고객님의 소중한 시간을 아껴드리겠습니다.
# ---------------
# [47]
# comment :  여긴 진짜 가성비 갑이다. 돈이 아깝지 않아!
# reply :  가성비 좋은 서비스를 위해 노력하겠습니다. 다음에도 만족하실 수 있도록 노력하겠습니다.
# ---------------
# [48]
# comment :  음식은 나쁘진 않았는데, 가격이 너무 비싸서 다시 오고 싶지 않아요.
# reply :  가격에 대한 의견 감사합니다. 가격과 가치의 균형을 맞추기 위해 노력하겠습니다.
# ---------------
# [49]
# comment :  처음 와봤는데, 기대이상이었어요. 앞으로 자주 올듯.
# reply :  기대 이상이었다니 기쁩니다! 앞으로도 기대 이상의 서비스를 제공하기 위해 노력하겠습니다. 다음에도 방문해 주시면 감사하겠습니다!
# ---------------
# [50]
# comment :  다른 사람들 후기보고 왔는데, 솔직히 그냥 그래요.
# reply :  후기보고 오셨다면, 더 나은 경험을 제공하지 못해 죄송합니다. 더 나은 경험을 제공하기 위해 노력하겠습니다.
# ---------------
# [51]
# comment :  분위기는 좋은데 가격이 너무 비싸네. ㅠㅠ
# reply :  분위기는 좋으셨지만 가격에 대한 의견 감사합니다. 가격에 대한 의견 감사합니다. 고객님의 의견을 소중히 여기며, 가격과 가치의 균형을 맞추기 위해 노력하겠습니다.
# ---------------
# [52]
# comment :  왜 사람들이 여기를 좋아하는지 모르겠네요. 다신 안 올 듯.
# reply :  사람들의 입맛도 만족시키지 못해 죄송합니다. 더 좋은 맛과 서비스로 보답하겠습니다.
# ---------------
# [53]
# comment :  가격이 좀 있지만 그만큼 음식이 퀄리티 있어요. 추천!
# reply :  가격에 만족하셨다니 감사합니다! 앞으로도 맛있는 음식으로 보답하겠습니다.
# ---------------
# [54]
# comment :  직원이 실수로 주문을 잘못 받았는데, 사과도 없고... ㅁㅊ
# reply :  주문 실수로 불편을 드려 죄송합니다. 앞으로는 더욱 주의 깊게 확인하겠습니다. 다시 한번 사과드립니다.
# ---------------
# [55]
# comment :  이 가격에 이런 맛, 진짜 ㄹㅇ 가성비 갑입니다.
# reply :  가성비 좋은 메뉴로 보답하겠습니다.
# ---------------
# [56]
# comment :  음식은 괜찮았는데 직원 태도가 좀...😡
# reply :  직원 태도에 대해 불편을 드려 죄송합니다. 직원 태도에 대한 교육을 강화하여 더 나은 서비스를 제공하겠습니다.
# ---------------
# [57]
# comment :  왜 이렇게 평이 좋은지 모르겠네요. 그냥 보통?
# reply :  기대에 미치지 못한 점 죄송합니다. 더 나은 서비스를 위해 노력하겠습니다.
# ---------------
# [58]
# comment :  음식이 식어서 나와서 좀 실망이었어요.
# reply :  음식이 식어서 나와서 실망하셨다니 정말 죄송합니다. 앞으로도 맛있는 음식으로 보답하겠습니다.
# ---------------
# [59]
# comment :  다른 가게하고는 비교도 안 되는 맛!! 😋👍
# reply :  다른 가게와 비교해 만족하셨다니 정말 기쁩니다! 앞으로도 변함없이 좋은 맛과 서비스로 보답하겠습니다.
# ---------------
# [60]
# comment :  흠.. 다들 맛있다고 해서 왔는데 나는 그냥 그랬어요.
# reply :  맛에 대한 기대치를 충족시키지 못해 죄송합니다. 더 좋은 맛으로 보답하겠습니다.
# ---------------
# [61]
# comment :  메뉴 설명을 너무 부실하게 해서 잘못 주문한 것 같아요.
# reply :  죄송합니다. 앞으로는 더욱 주의 깊게 서비스하겠습니다.
# ---------------
# [62]
# comment :  음식은 진짜 맛나, 근데 가격이 좀 ㅠㅠ
# reply :  음식에 대한 기대치를 충족시키지 못해 죄송합니다. 가격과 가치의 균형을 위해 노력하겠습니다.
# ---------------
# [63]
# comment :  왜 이렇게 평이 좋은지 모르겠음.. 나에겐 그냥 그랬어.
# reply :  기대에 미치지 못한 점 죄송합니다. 더 나은 서비스를 위해 노력하겠습니다.
# ---------------
# [64]
# comment :  식당 분위기가 너무 시끄러워서 대화하기 힘들었어요.
# reply :  식당 분위기에 대한 불편을 드려 죄송합니다. 대화하기 더 편안하도록 노력하겠습니다.
# ---------------
# [65]
# comment :  음식이 너무 짜서 물만 계속 마셨네요...
# reply :  음식의 짠맛에 대한 피드백 감사합니다. 조미료 사용을 조절하도록 하겠습니다.
# ---------------
# [66]
# comment :  이런 맛을 찾아 헤맸는데, 드디어 찾은 느낌이에요!
# reply :  만족하셨다니 감사합니다! 계속해서 좋은 맛을 제공하겠습니다.
# ---------------
# [67]
# comment :  소스와 재료의 조화가 너무 완벽해요. 천재적인 조합!
# reply :  소스와 재료의 조화가 마음에 드셨다니 감사합니다. 앞으로도 소스와 재료의 조화가 잘 되도록 노력하겠습니다.
# ---------------
# [68]
# comment :  직원 태도진짜불쾌함.. 다시는안올거에요.
# reply :  직원 태도에 대해 불편을 드려 죄송합니다. 직원 교육을 더 철저히 진행하겠습니다.
# ---------------
# [69]
# comment :  황홀한 맛의 디저트였어요. 여기 팥빙수 강추!
# reply :  황홀한 맛의 디저트를 좋아해주셔서 감사합니다! 앞으로도 변함없이 최고의 맛과 서비스로 보답하겠습니다.
# ---------------
# [70]
# comment :  직원들이 너무 바빠서 주문도 제대로 못 들어줘요.
# reply :  불편을 드려 죄송합니다. 주문 확인을 더 철저히 하겠습니다.
# ---------------
# [71]
# comment :  직원분이 계산할때 잘못해서 더 내라고 함. 나중에 환불해줬지만 기분이 좀 그랬어
# reply :  죄송합니다. 앞으로는 더욱 주의 깊게 확인하겠습니다. 불편을 드려 죄송하며, 다음 방문시 더 나은 서비스를 제공하기 위해 노력하겠습니다.
# ---------------
# [72]
# comment :  음료가 너무 진해서 물을 따로 달라고 했어요.
# reply :  물은 진하고 맛에 대한 피드백 감사합니다. 음료는 마음에 들어주셔서 감사합니다. 다음에는 더 좋은 맛으로 보답하겠습니다.
# ---------------
# [73]
# comment :  분위기 좋고 직원들도 친절한데 음식 맛이 좀...?
# reply :  분위기와 음식 맛에 만족하셨다니 감사합니다. 앞으로도 편안하고 즐거운 식사 환경을 제공하기 위해 노력하겠습니다.
# ---------------
# [74]
# comment :  전체적으로는 좋은데 소리가 너무 크게 나와서 대화하기 힘들었어요.
# reply :  소리에 대한 피드백 감사합니다. 더 원활한 대화 환경을 제공하기 위해 노력하겠습니다.
# ---------------
# [75]
# comment :  주방에서 뭔가 큰 소리가 나서 좀 놀랐어요. 조금 무서웠습니다.
# reply :  소음으로 인해 불편을 드려 죄송합니다. 주방의 작업 환경 개선을 통해 더 쾌적한 식사 환경을 제공하도록 노력하겠습니다.
# ---------------
# [76]
# comment :  이렇게 맛있는 집 처음이에요ㅠㅠ ❤️👍
# reply :  감사합니다! 앞으로도 좋은 맛과 서비스로 보답하겠습니다.
# ---------------
# [77]
# comment :  가격대비 양이너무적어요; 피자는맛있었는데
# reply :  가격대비 양, 질에 대한 피드백 감사합니다. 고객님의 의견을 반영하여 더욱 개선하겠습니다.
# ---------------
# [78]
# comment :  서비스가 좋긴한데 음식이 나에게는 안 맞았어.
# reply :  서비스에 만족하셨다니 다행입니다. 음식의 품질에 대해서는 더욱 노력하겠습니다.
# ---------------
# [79]
# comment :  어머니랑 와서 먹었는데 둘 다 만족했어요!
# reply :  어머니께서 만족하셨다니 기쁩니다! 앞으로도 좋은 추억 만들어드릴게요!
# ---------------
# [80]
# comment :  음식이 너무 짜서 다른 음식점이랑 비교했을 때 별로였어요.
# reply :  음식의 짠맛에 대한 피드백 감사합니다. 조미료 사용을 조절하도록 하겠습니다.
# ---------------
# [81]
# comment :  정말 전통의 맛을 잘 지키는 곳이에요. 추억의 맛.
# reply :  감사합니다! 앞으로도 변함없이 전통 맛을 지키겠습니다.
# ---------------
# [82]
# comment :  실내 온도가 너무 높아서 더웠어요. 에어컨 좀 틀어주세요.
# reply :  실내 온도에 대한 피드백 감사합니다. 에어컨을 틀어주셔서 더위를 식혀주시면 감사하겠습니다.
# ---------------
# [83]
# comment :  다른 지점보다 서비스가 좋아요. 여기 직원들이 친절해요.
# reply :  직원들의 친절함이 기억에 남아주셔서 감사합니다! 앞으로도 최선을 다하겠습니다.
# ---------------
# [84]
# comment :  음식점 위치가 좀 애매해서 찾기 힘들었어요.
# reply :  위치 관련 불편을 드려 죄송합니다. 위치 정보를 더욱 명확하게 안내하겠습니다.
# ---------------
# [85]
# comment :  완전 대박...! 이런 맛은 처음이야 ㅋㅋ
# reply :  완전 대박 맛에 만족하셨다니 정말 기쁩니다! 고객님의 소중한 피드백을 통해 더욱 향상된 맛을 제공하도록 노력하겠습니다. 다음에도 저희 가게를 찾아주셔서 감사합니다.
# ---------------
# [86]
# comment :  음식이 맛있긴한데 가격대비 양이 너무 적어서 별로였음.
# reply :  양에 대한 의견 감사합니다. 가격과 음식에 대한 고려를 더 하도록 하겠습니다.
# ---------------
# [87]
# comment :  다른 지점보다 서비스가 좋아요. 여기 직원들이 친절해요.
# reply :  직원들의 친절함이 기억에 남아주셔서 감사합니다! 앞으로도 최선을 다하겠습니다.
# ---------------
# [88]
# comment :  음식은 괜찮았는데 뒷편에서 뭔가 큰소리가 나서 식사하는데 불편했어요.
# reply :  소리에 대한 피드백 감사합니다. 앞으로는 더욱 주의 깊게 서비스하겠습니다.
# ---------------
# [89]
# comment :  메뉴판에 있는 사진과 너무 다르게 나와서 기분이 안 좋았습니다.
# reply :  죄송합니다. 사진과 실제의 차이로 불편을 드려 죄송합니다.
# ---------------
# [90]
# comment :  음식 나오는 데 너무 오래 걸려서 기다리기 지루했어요.
# reply :  음식 대기 시간이 길어져 불편을 드려 죄송합니다. 앞으로는 더욱 주의 깊게 대기 시간을 운영하겠습니다.
# ---------------
# [91]
# comment :  너무나도 맛있었어요. 이전에 갔던 다른 곳과는 비교도 안 됩니다!
# reply :  만족하셨다니 감사합니다! 앞으로도 변함없이 좋은 맛과 서비스로 보답하겠습니다.
# ---------------
# [92]
# comment :  친구 추천으로 왔는데, 후회 없는 선택이었어요.
# reply :  친구의 추천으로 오셨다니 감사합니다! 다음에도 방문 부탁드립니다.
# ---------------
# [93]
# comment :  여기 진짜 맛집이네요! 서비스도 좋아요.
# reply :  감사합니다! 앞으로도 만족하실 수 있는 맛집을 제공하기 위해 노력하겠습니다.
# ---------------
# [94]
# comment :  예약했는데도 기다리게 해서 기분이 좋진 않았어요.
# reply :  예약에도 불구하고 기다리게 해드려 죄송합니다. 앞으로는 더욱 철저한 예약 관리로 고객님의 소중한 시간을 아껴드리겠습니다.
# ---------------
# [95]
# comment :  가성비 최고! 이 가격에 이런 맛은 정말 만족스러워요.
# reply :  가성비 좋은 메뉴를 제공하기 위해 노력하겠습니다. 다음에도 저희 가게를 찾아주셔서 감사합니다. 항상 최고의 맛과 서비스를 제공하기 위해 노력하겠습니다.
# ---------------
# [96]
# comment :  와... 여기김치... 말도안됨... ㅁㅊ...
# reply :  김치 섭취를 규제하는 것이 타당하냐는 의견 감사드립니다. 더 명확하게 김치 섭취를 규제할 수 있도록 노력하겠습니다.
# ---------------
# [97]
# comment :  주문한 지 40분 넘게 기다려서 음식 나왔네요...
# reply :  주문 대기 시간이 길었다는 점, 진심으로 죄송합니다. 주문 대기 시간이 길었다는 점, 진심으로 사과드립니다. 앞으로는 더욱 주의 깊게 서비스하겠습니다.
# ---------------
# [98]
# comment :  아이들이랑 왔는데, 키즈 메뉴도 생각보다 맛있었어요!
# reply :  아이들과 함께 즐거운 시간 보내셨다니 기쁩니다! 앞으로도 다양한 연령대의 고객님들이 만족할 수 있는 메뉴를 제공하기 위해 노력하겠습니다. 다음에도 기대에 부응하는 맛과 서비스로 모시겠습니다!
# ---------------
# [99]
# comment :  오랜만에 외식을 했는데, 이런 결과를 보게 될 줄은 몰랐네요. 음식도 별로고, 서비스도 매우 불친절했습니다. 다시는 오고 싶지 않아요.
# reply :  식사와 서비스가 만족스럽지 않았다니 정말 죄송합니다. 고객님의 소중한 피드백을 통해 서비스와 음식 품질 개선에 힘쓰겠습니다. 다음에도 저희 가게를 찾아주셔서 감사합니다. 불편을 드려<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# ---------------
